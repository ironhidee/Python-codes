# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn import model_selection

# %%
from sklearn.preprocessing import LabelEncoder
number = LabelEncoder()

# %%
train = pd.io.parsers.read_csv('data_812513.csv')

# %%
train.describe()
# Out:
#          Engine  IGVA_VAL0  IGVB_VAL0   IGVSEL_VAL0  Prior Shutdown  \
# count   89631.0    89631.0    89631.0  89631.000000    89631.000000
# mean   812513.0        0.0        0.0     73.973034        0.182671
# std         0.0        0.0        0.0     23.426274        0.386399
# min    812513.0        0.0        0.0      0.000000        0.000000
# 25%    812513.0        0.0        0.0     78.000000        0.000000
# 50%    812513.0        0.0        0.0     83.000000        0.000000
# 75%    812513.0        0.0        0.0     87.000000        0.000000
# max    812513.0        0.0        0.0     98.000000        1.000000
#
#               Event       Failure           RUF    MWSEL_VAL0     N25A_VAL0  \
# count  89631.000000  89631.000000  89631.000000  89631.000000  89631.000000
# mean       0.000011      0.003347     35.290860     28.548831   8479.189800
# std        0.003340      0.057757     18.835893     13.682305   3877.540046
# ...

# %%
train.head()
# Out:
#    Engine       DATETIME  IGVA_VAL0  IGVB_VAL0  IGVSEL_VAL0  Prior Shutdown  \
# 0  812513  8/1/2015 0:00          0          0           80               0
# 1  812513  8/1/2015 0:01          0          0           79               0
# 2  812513  8/1/2015 0:02          0          0           80               0
# 3  812513  8/1/2015 0:03          0          0           80               0
# 4  812513  8/1/2015 0:04          0          0           80               0
#
#    Event  Failure        RUF  MWSEL_VAL0  ...    TGBEB_VAL0  TGBESEL_VAL0  \
# 0      0        0  67.694444   33.989981  ...           248           249
# 1      0        0  67.693750   33.860014  ...           248           249
# 2      0        0  67.693056   33.950006  ...           248           250
# 3      0        0  67.692361   33.990006  ...           247           248
# 4      0        0  67.691667   34.030015  ...           247           248
#
# ...

# %%
train1 = train.drop('DATETIME', axis = 1)

# %%
train1.ALARM.fillna(0, inplace=True)

# %%
y = train1.ALARM.ravel()

# %%
train1 = train1.drop('ALARM', axis = 1)

# %%
x = train1.values

# %%
dtrain = xgb.DMatrix(x, label = y)

# %%
params = {'max_depth':2, 'eta':1, 'objective':'multi:softmax', 'num_class': 2}

# %%
gb = xgb.cv(params, dtrain, num_boost_round=10, nfold=3)

# %%
gb
# Out:
#    test-merror-mean  test-merror-std  train-merror-mean  train-merror-std
# 0          0.000033         0.000047           0.000033          0.000024
# 1          0.000033         0.000047           0.000033          0.000024
# 2          0.000033         0.000047           0.000033          0.000024
# 3          0.000033         0.000047           0.000033          0.000024
# 4          0.000033         0.000047           0.000033          0.000024
# 5          0.000033         0.000047           0.000033          0.000024
# 6          0.000033         0.000047           0.000033          0.000024
# 7          0.000044         0.000042           0.000028          0.000021
# 8          0.000033         0.000047           0.000033          0.000024
# 9          0.000033         0.000047           0.000033          0.000024
