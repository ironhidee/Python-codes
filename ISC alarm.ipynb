# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn import model_selection
# Out:
# C:\Users\Rohit\Anaconda3\envs\Xgboost\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
from sklearn.preprocessing import LabelEncoder
number = LabelEncoder()

# %%
train = pd.io.parsers.read_csv('data_812513.csv')

# %%
train.describe()
# Out:
#          Engine  IGVA_VAL0  IGVB_VAL0   IGVSEL_VAL0  Prior Shutdown  \
# count   89631.0    89631.0    89631.0  89631.000000    89631.000000
# mean   812513.0        0.0        0.0     73.973034        0.182671
# std         0.0        0.0        0.0     23.426274        0.386399
# min    812513.0        0.0        0.0      0.000000        0.000000
# 25%    812513.0        0.0        0.0     78.000000        0.000000
# 50%    812513.0        0.0        0.0     83.000000        0.000000
# 75%    812513.0        0.0        0.0     87.000000        0.000000
# max    812513.0        0.0        0.0     98.000000        1.000000
#
#               Event       Failure           RUF    MWSEL_VAL0     N25A_VAL0  \
# count  89631.000000  89631.000000  89631.000000  89631.000000  89631.000000
# mean       0.000011      0.003347     35.290860     28.548831   8479.189800
# std        0.003340      0.057757     18.835893     13.682305   3877.540046
# ...

# %%
train1 = train.drop(['DATETIME','IGVA_VAL0','IGVB_VAL0','VBVA_VAL0','VBVB_VAL0','VBVB_VAL0_FLAG','Engine'] , axis = 1)

# %%
train1.ALARM.fillna(0, inplace=True)
train1 = pd.get_dummies(data = train1, columns = ['Prior Shutdown','Event','Failure'])

# %%
y = train1.ALARM.ravel()

# %%
train1 = train1.drop('ALARM', axis = 1)

# %%
x = train1.values

# %%
dtrain = xgb.DMatrix(x, label = y)

# %%
params = {'max_depth':10, 'eta':1, 'objective':'multi:softprob', 'num_class': 2, 'min_child_weight':1.2, 'subsample': 0.5, 'colsample_bytree' :0.3}

# %%
gb = xgb.cv(params, dtrain, num_boost_round=10, nfold=5)

# %%
gb
# Out:
#    test-merror-mean  test-merror-std  train-merror-mean  train-merror-std
# 0          0.000034         0.000045           0.000034          0.000011
# 1          0.000034         0.000045           0.000034          0.000011
# 2          0.000034         0.000045           0.000034          0.000011
# 3          0.000034         0.000045           0.000034          0.000011
# 4          0.000034         0.000045           0.000034          0.000011
# 5          0.000034         0.000045           0.000034          0.000011
# 6          0.000034         0.000045           0.000034          0.000011
# 7          0.000034         0.000045           0.000034          0.000011
# 8          0.000034         0.000045           0.000034          0.000011
# 9          0.000034         0.000045           0.000034          0.000011
